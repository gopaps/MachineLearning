# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
#Langkah 1: Membuat Data Dummy untuk Klasifikasi data
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=42)

#Langkah 2: Praproses Data
scaler = StandardScaler()
X = scaler.fit_transform(X)  # Normalisasi features

# Membagi Data Menjadi Set Pelatihan dan Pengujian
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Mengonversi Data ke Tensors PyTorch
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# %%
# Step 3: Define MLP model
def create_mlp(input_size, hidden_layers, hidden_neurons, activation_function):
    layers = []
    # Lapisan Input ke Lapisan Tersembunyi Pertama
    layers.append(nn.Linear(input_size, hidden_neurons))
    # Menambahkan Lapisan Tersembunyi
    for _ in range(hidden_layers - 1):
        layers.append(nn.Linear(hidden_neurons, hidden_neurons))
    
    # Memilih Fungsi Aktivasi
    if activation_function == 'linear':
        activation = nn.Identity()
    elif activation_function == 'Sigmoid':
        activation = nn.Sigmoid()
    elif activation_function == 'ReLU':
        activation = nn.ReLU()
    elif activation_function == 'Softmax':
        activation = nn.Softmax(dim=1)
    elif activation_function == 'Tanh':
        activation = nn.Tanh()
    
    # Lapisan Output
    layers.append(nn.Linear(hidden_neurons, 2))  # Menghasilkan 2 Kelas (0 atau 1)
    
    # Menggabungkan Semua Lapisan
    model = nn.Sequential(*layers)
    return model

# %%
# Langkah 4: Melatih dan Mengevaluasi Model
def train_and_evaluate(model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate):
    # DataLoader untuk pelatihan dalam batch
    train_data = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

    # Optimizer (Adam) dan fungsi loss (CrossEntropyLoss untuk klasifikasi)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    # Loop pelatihan
    model.train()  # Mengatur model ke mode pelatihan
    for epoch in range(epochs):
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()  # Mengatur ulang gradien
            output = model(X_batch)  # Proses forward
            loss = criterion(output, y_batch)  # Menghitung loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Memperbarui parameter model

    # Evaluasi setelah pelatihan
    model.eval()  # Mengatur model ke mode evaluasi
    with torch.no_grad():  # Menonaktifkan perhitungan gradien untuk efisiensi
        # Akurasi pelatihan
        train_output = model(X_train_tensor)
        train_pred = torch.argmax(train_output, dim=1)  # Mendapatkan kelas yang diprediksi
        train_accuracy = accuracy_score(y_train_tensor.numpy(), train_pred.numpy())  # Menghitung akurasi pelatihan
        train_loss = criterion(train_output, y_train_tensor).item()  # Menghitung loss pelatihan

        # Akurasi pengujian
        test_output = model(X_test_tensor)
        test_pred = torch.argmax(test_output, dim=1)  # Mendapatkan kelas yang diprediksi
        test_accuracy = accuracy_score(y_test_tensor.numpy(), test_pred.numpy())  # Menghitung akurasi pengujian
        test_loss = criterion(test_output, y_test_tensor).item()  # Menghitung loss pengujian

    return train_accuracy, train_loss, test_accuracy, test_loss  # Mengembalikan hasil

# %%
# Langkah 5: Bereksperimen dengan Hyperparameter
hidden_layers_options = [1, 2, 3]  # Jumlah lapisan tersembunyi
hidden_neurons_options = [4, 8, 16, 32, 64]  # Jumlah neuron pada setiap lapisan tersembunyi
activation_functions = ['linear', 'Sigmoid', 'ReLU', 'Softmax', 'Tanh']  # Fungsi aktivasi
epochs_options = [25, 50, 100, 250]  # Jumlah epoch
learning_rates = [0.1, 0.01, 0.001, 0.0001]  # Tingkat pembelajaran
batch_sizes = [64, 128, 256, 512]  # Ukuran batch

# Melacak hasil eksperimen
results = []  # Untuk menyimpan hasil dari setiap eksperimen
best_result = None
worst_result = None
best_per_activation = {activation: None for activation in activation_functions}  # Melacak hasil terbaik untuk setiap fungsi aktivasi

# Loop melalui semua kombinasi hyperparameter
for hidden_layers in hidden_layers_options:
    for hidden_neurons in hidden_neurons_options:
        for activation_function in activation_functions:
            for epochs in epochs_options:
                for learning_rate in learning_rates:
                    for batch_size in batch_sizes:
                        # Mencetak konfigurasi eksperimen saat ini
                        print(f"Melatih dengan {hidden_layers} lapisan tersembunyi, {hidden_neurons} neuron, fungsi aktivasi {activation_function}, "
                              f"{epochs} epoch, tingkat pembelajaran {learning_rate}, ukuran batch {batch_size}")

                        # Membuat model untuk setiap kombinasi hyperparameter
                        model = create_mlp(X_train_tensor.shape[1], hidden_layers, hidden_neurons, activation_function)
                        
                        # Melatih dan mengevaluasi model
                        train_acc, train_loss, test_acc, test_loss = train_and_evaluate(
                            model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate
                        )

                        # Menyimpan hasil
                        results.append({
                            'Hidden Layers': hidden_layers,
                            'Hidden Neurons': hidden_neurons,
                            'Activation Function': activation_function,
                            'Epochs': epochs,
                            'Learning Rate': learning_rate,
                            'Batch Size': batch_size,
                            'Train Accuracy': train_acc,
                            'Train Loss': train_loss,
                            'Test Accuracy': test_acc,
                            'Test Loss': test_loss
                        })

                        # Mencetak hasil akhir dari eksperimen ini
                        print(f"Akurasi Pelatihan: {train_acc * 100:.2f}%")
                        print(f"Loss Pelatihan: {train_loss:.4f}")
                        print(f"Akurasi Pengujian: {test_acc * 100:.2f}%")
                        print(f"Loss Pengujian: {test_loss:.4f}\n")

                        # Memperbarui hasil terbaik dan terburuk
                        if best_result is None atau test_acc > best_result['Test Accuracy']:
                            best_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
                        if worst_result is None atau test_acc < worst_result['Test Accuracy']:
                            worst_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }

                        # Melacak konfigurasi terbaik untuk setiap fungsi aktivasi
                        if best_per_activation[activation_function] is None atau test_acc > best_per_activation[activation_function]['Test Accuracy']:
                            best_per_activation[activation_function] = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
# Out:
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3083
# Test Accuracy: 85.67%
# Test Loss: 0.3808
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3080
# Test Accuracy: 84.67%
# Test Loss: 0.3856
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3074
# Test Accuracy: 85.33%
# Test Loss: 0.3790
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3101
# Test Accuracy: 83.67%
# Test Loss: 0.3812
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3074
# Test Accuracy: 85.00%
# Test Loss: 0.3800
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3077
# Test Accuracy: 85.67%
# Test Loss: 0.3770
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3074
# Test Accuracy: 84.67%
# Test Loss: 0.3846
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3072
# Test Accuracy: 85.33%
# Test Loss: 0.3819
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 84.14%
# Train Loss: 0.4666
# Test Accuracy: 79.33%
# Test Loss: 0.5034
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.71%
# Train Loss: 0.4544
# Test Accuracy: 81.67%
# Test Loss: 0.4791
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 76.86%
# Train Loss: 0.5619
# Test Accuracy: 73.67%
# Test Loss: 0.5680
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 70.14%
# Train Loss: 0.6072
# Test Accuracy: 67.67%
# Test Loss: 0.6182
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 51.86%
# Train Loss: 0.7070
# Test Accuracy: 55.00%
# Test Loss: 0.6908
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 52.29%
# Train Loss: 0.6893
# Test Accuracy: 54.00%
# Test Loss: 0.6668
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 54.71%
# Train Loss: 0.7000
# Test Accuracy: 53.33%
# Test Loss: 0.6978
#
# Training with 1 hidden layers, 4 neurons, linear activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 38.57%
# Train Loss: 0.7971
# Test Accuracy: 43.33%
# Test Loss: 0.7755
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3221
# Test Accuracy: 84.33%
# Test Loss: 0.4148
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3104
# Test Accuracy: 84.33%
# Test Loss: 0.3849
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3087
# Test Accuracy: 85.33%
# Test Loss: 0.3764
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3152
# Test Accuracy: 85.00%
# Test Loss: 0.3769
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3075
# Test Accuracy: 85.33%
# Test Loss: 0.3783
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3072
# Test Accuracy: 85.33%
# Test Loss: 0.3803
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3071
# Test Accuracy: 85.00%
# Test Loss: 0.3810
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3080
# Test Accuracy: 85.33%
# Test Loss: 0.3824
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3121
# Test Accuracy: 85.33%
# Test Loss: 0.3759
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3594
# Test Accuracy: 84.67%
# Test Loss: 0.4017
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.4115
# Test Accuracy: 84.33%
# Test Loss: 0.4474
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 82.86%
# Train Loss: 0.5379
# Test Accuracy: 79.33%
# Test Loss: 0.5564
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 69.00%
# Train Loss: 0.6156
# Test Accuracy: 68.33%
# Test Loss: 0.6171
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 47.43%
# Train Loss: 0.7666
# Test Accuracy: 49.67%
# Test Loss: 0.7394
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 49.29%
# Train Loss: 0.7337
# Test Accuracy: 51.67%
# Test Loss: 0.7290
#
# Training with 1 hidden layers, 4 neurons, linear activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 49.86%
# Train Loss: 0.7332
# Test Accuracy: 48.33%
# Test Loss: 0.7371
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3147
# Test Accuracy: 87.00%
# Test Loss: 0.3978
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3098
# Test Accuracy: 86.67%
# Test Loss: 0.3884
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3092
# Test Accuracy: 84.67%
# Test Loss: 0.3920
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3091
# Test Accuracy: 85.67%
# Test Loss: 0.3791
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3075
# Test Accuracy: 85.00%
# Test Loss: 0.3883
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3075
# Test Accuracy: 85.00%
# Test Loss: 0.3797
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3070
# Test Accuracy: 84.67%
# Test Loss: 0.3826
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3077
# Test Accuracy: 85.67%
# Test Loss: 0.3769
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3069
# Test Accuracy: 85.33%
# Test Loss: 0.3807
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3077
# Test Accuracy: 84.67%
# Test Loss: 0.3780
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3417
# Test Accuracy: 84.33%
# Test Loss: 0.3901
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3766
# Test Accuracy: 86.00%
# Test Loss: 0.4148
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 84.00%
# Train Loss: 0.5028
# Test Accuracy: 81.00%
# Test Loss: 0.5313
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 54.86%
# Train Loss: 0.6872
# Test Accuracy: 54.00%
# Test Loss: 0.6862
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 68.71%
# Train Loss: 0.6139
# Test Accuracy: 63.00%
# Test Loss: 0.6168
#
# Training with 1 hidden layers, 4 neurons, linear activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 61.43%
# Train Loss: 0.6402
# Test Accuracy: 62.33%
# Test Loss: 0.6463
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 87.29%
# Train Loss: 0.3179
# Test Accuracy: 84.33%
# Test Loss: 0.3873
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3090
# Test Accuracy: 85.00%
# Test Loss: 0.3831
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3087
# Test Accuracy: 84.33%
# Test Loss: 0.3873
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3085
# Test Accuracy: 86.00%
# Test Loss: 0.3862
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3071
# Test Accuracy: 85.00%
# Test Loss: 0.3813
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3072
# Test Accuracy: 85.67%
# Test Loss: 0.3835
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3070
# Test Accuracy: 84.67%
# Test Loss: 0.3815
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3075
# Test Accuracy: 85.00%
# Test Loss: 0.3819
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3069
# Test Accuracy: 84.67%
# Test Loss: 0.3811
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3070
# Test Accuracy: 85.00%
# Test Loss: 0.3805
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3069
# Test Accuracy: 85.00%
# Test Loss: 0.3804
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3075
# Test Accuracy: 85.33%
# Test Loss: 0.3779
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3578
# Test Accuracy: 85.67%
# Test Loss: 0.3998
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 84.86%
# Train Loss: 0.5064
# Test Accuracy: 81.67%
# Test Loss: 0.5254
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 84.14%
# Train Loss: 0.5200
# Test Accuracy: 79.00%
# Test Loss: 0.5456
#
# Training with 1 hidden layers, 4 neurons, linear activation, 250 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 50.14%
# Train Loss: 0.6931
# Test Accuracy: 51.33%
# Test Loss: 0.6890
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3169
# Test Accuracy: 85.00%
# Test Loss: 0.3841
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3095
# Test Accuracy: 84.67%
# Test Loss: 0.3837
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3095
# Test Accuracy: 86.00%
# Test Loss: 0.3826
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3098
# Test Accuracy: 85.00%
# Test Loss: 0.3916
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3073
# Test Accuracy: 85.67%
# Test Loss: 0.3823
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3076
# Test Accuracy: 84.67%
# Test Loss: 0.3780
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3073
# Test Accuracy: 84.67%
# Test Loss: 0.3852
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3085
# Test Accuracy: 84.33%
# Test Loss: 0.3900
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3421
# Test Accuracy: 83.00%
# Test Loss: 0.3968
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 84.86%
# Train Loss: 0.4908
# Test Accuracy: 82.00%
# Test Loss: 0.5092
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 82.57%
# Train Loss: 0.4926
# Test Accuracy: 78.00%
# Test Loss: 0.5202
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 70.57%
# Train Loss: 0.6039
# Test Accuracy: 68.67%
# Test Loss: 0.6129
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 50.71%
# Train Loss: 0.7331
# Test Accuracy: 48.67%
# Test Loss: 0.7615
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 51.43%
# Train Loss: 0.7521
# Test Accuracy: 48.67%
# Test Loss: 0.7804
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 57.14%
# Train Loss: 0.6753
# Test Accuracy: 55.33%
# Test Loss: 0.6862
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 56.00%
# Train Loss: 0.6791
# Test Accuracy: 57.33%
# Test Loss: 0.6868
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 87.43%
# Train Loss: 0.3184
# Test Accuracy: 83.00%
# Test Loss: 0.4218
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3104
# Test Accuracy: 86.33%
# Test Loss: 0.3769
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3077
# Test Accuracy: 85.00%
# Test Loss: 0.3829
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3106
# Test Accuracy: 86.00%
# Test Loss: 0.3751
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3073
# Test Accuracy: 85.33%
# Test Loss: 0.3839
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3075
# Test Accuracy: 86.00%
# Test Loss: 0.3782
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3070
# Test Accuracy: 84.67%
# Test Loss: 0.3821
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3080
# Test Accuracy: 85.33%
# Test Loss: 0.3782
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3102
# Test Accuracy: 85.67%
# Test Loss: 0.3758
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3531
# Test Accuracy: 85.33%
# Test Loss: 0.3987
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 83.57%
# Train Loss: 0.5235
# Test Accuracy: 80.67%
# Test Loss: 0.5456
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 80.29%
# Train Loss: 0.5637
# Test Accuracy: 82.00%
# Test Loss: 0.5705
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 62.00%
# Train Loss: 0.6366
# Test Accuracy: 61.00%
# Test Loss: 0.6519
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 58.86%
# Train Loss: 0.6582
# Test Accuracy: 57.33%
# Test Loss: 0.6659
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 42.43%
# Train Loss: 0.7243
# Test Accuracy: 40.33%
# Test Loss: 0.7293
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 64.86%
# Train Loss: 0.6625
# Test Accuracy: 60.67%
# Test Loss: 0.6683
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3097
# Test Accuracy: 85.00%
# Test Loss: 0.3855
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3134
# Test Accuracy: 84.67%
# Test Loss: 0.4020
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3072
# Test Accuracy: 84.67%
# Test Loss: 0.3826
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 87.71%
# Train Loss: 0.3115
# Test Accuracy: 84.00%
# Test Loss: 0.3905
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3073
# Test Accuracy: 85.67%
# Test Loss: 0.3798
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3073
# Test Accuracy: 84.67%
# Test Loss: 0.3822
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3070
# Test Accuracy: 85.33%
# Test Loss: 0.3815
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3075
# Test Accuracy: 84.67%
# Test Loss: 0.3824
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3069
# Test Accuracy: 85.00%
# Test Loss: 0.3812
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3085
# Test Accuracy: 84.33%
# Test Loss: 0.3751
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3446
# Test Accuracy: 86.33%
# Test Loss: 0.3905
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3754
# Test Accuracy: 85.67%
# Test Loss: 0.4119
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 83.14%
# Train Loss: 0.4969
# Test Accuracy: 78.00%
# Test Loss: 0.5150
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 75.86%
# Train Loss: 0.5591
# Test Accuracy: 75.00%
# Test Loss: 0.5668
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 78.00%
# Train Loss: 0.5442
# Test Accuracy: 71.33%
# Test Loss: 0.5767
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 48.00%
# Train Loss: 0.7744
# Test Accuracy: 46.67%
# Test Loss: 0.7895
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3330
# Test Accuracy: 84.00%
# Test Loss: 0.4188
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3095
# Test Accuracy: 85.00%
# Test Loss: 0.3736
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3081
# Test Accuracy: 83.67%
# Test Loss: 0.3823
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3090
# Test Accuracy: 86.33%
# Test Loss: 0.3777
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3070
# Test Accuracy: 85.00%
# Test Loss: 0.3813
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3073
# Test Accuracy: 85.00%
# Test Loss: 0.3825
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3070
# Test Accuracy: 85.00%
# Test Loss: 0.3824
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3074
# Test Accuracy: 85.33%
# Test Loss: 0.3841
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3069
# Test Accuracy: 84.67%
# Test Loss: 0.3813
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3070
# Test Accuracy: 85.33%
# Test Loss: 0.3811
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3069
# Test Accuracy: 84.67%
# Test Loss: 0.3810
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3078
# Test Accuracy: 85.00%
# Test Loss: 0.3776
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 87.57%
# Train Loss: 0.3977
# Test Accuracy: 83.33%
# Test Loss: 0.4375
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 86.14%
# Train Loss: 0.4819
# Test Accuracy: 81.33%
# Test Loss: 0.5099
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 70.71%
# Train Loss: 0.5790
# Test Accuracy: 67.33%
# Test Loss: 0.6014
#
# Training with 1 hidden layers, 4 neurons, Sigmoid activation, 250 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 49.43%
# Train Loss: 0.7189
# Test Accuracy: 51.67%
# Test Loss: 0.7026
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3167
# Test Accuracy: 84.33%
# Test Loss: 0.4058
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3133
# Test Accuracy: 84.67%
# Test Loss: 0.4020
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3092
# Test Accuracy: 85.33%
# Test Loss: 0.3779
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3133
# Test Accuracy: 85.00%
# Test Loss: 0.3972
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3074
# Test Accuracy: 85.33%
# Test Loss: 0.3786
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3074
# Test Accuracy: 85.33%
# Test Loss: 0.3806
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3071
# Test Accuracy: 84.67%
# Test Loss: 0.3832
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3097
# Test Accuracy: 85.67%
# Test Loss: 0.3813
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3490
# Test Accuracy: 84.67%
# Test Loss: 0.3963
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 59.57%
# Train Loss: 0.6635
# Test Accuracy: 57.00%
# Test Loss: 0.6708
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 76.43%
# Train Loss: 0.6010
# Test Accuracy: 77.67%
# Test Loss: 0.6060
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 51.57%
# Train Loss: 0.6988
# Test Accuracy: 51.67%
# Test Loss: 0.6899
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 61.71%
# Train Loss: 0.6534
# Test Accuracy: 61.00%
# Test Loss: 0.6603
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 62.71%
# Train Loss: 0.6727
# Test Accuracy: 59.33%
# Test Loss: 0.6771
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 35.00%
# Train Loss: 0.7882
# Test Accuracy: 35.67%
# Test Loss: 0.7938
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 35.43%
# Train Loss: 0.7808
# Test Accuracy: 36.67%
# Test Loss: 0.7947
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3098
# Test Accuracy: 86.00%
# Test Loss: 0.3781
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3101
# Test Accuracy: 84.67%
# Test Loss: 0.3796
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3077
# Test Accuracy: 85.00%
# Test Loss: 0.3804
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3094
# Test Accuracy: 84.00%
# Test Loss: 0.3890
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3072
# Test Accuracy: 85.00%
# Test Loss: 0.3813
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3075
# Test Accuracy: 85.67%
# Test Loss: 0.3804
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3070
# Test Accuracy: 85.00%
# Test Loss: 0.3817
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3077
# Test Accuracy: 85.00%
# Test Loss: 0.3801
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3084
# Test Accuracy: 85.33%
# Test Loss: 0.3778
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3300
# Test Accuracy: 86.67%
# Test Loss: 0.3801
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 79.43%
# Train Loss: 0.5838
# Test Accuracy: 74.67%
# Test Loss: 0.6005
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 82.00%
# Train Loss: 0.4442
# Test Accuracy: 76.67%
# Test Loss: 0.4881
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 59.14%
# Train Loss: 0.6586
# Test Accuracy: 54.67%
# Test Loss: 0.6819
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 71.71%
# Train Loss: 0.5896
# Test Accuracy: 72.33%
# Test Loss: 0.5842
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 53.29%
# Train Loss: 0.6822
# Test Accuracy: 54.00%
# Test Loss: 0.6858
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 49.14%
# Train Loss: 0.7012
# Test Accuracy: 55.67%
# Test Loss: 0.6795
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3087
# Test Accuracy: 86.00%
# Test Loss: 0.3772
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3084
# Test Accuracy: 84.67%
# Test Loss: 0.3894
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3093
# Test Accuracy: 84.33%
# Test Loss: 0.3895
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3128
# Test Accuracy: 84.00%
# Test Loss: 0.4041
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3072
# Test Accuracy: 85.00%
# Test Loss: 0.3825
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3075
# Test Accuracy: 84.67%
# Test Loss: 0.3829
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3070
# Test Accuracy: 85.33%
# Test Loss: 0.3826
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3076
# Test Accuracy: 84.67%
# Test Loss: 0.3821
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3069
# Test Accuracy: 85.00%
# Test Loss: 0.3812
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3078
# Test Accuracy: 84.67%
# Test Loss: 0.3778
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3599
# Test Accuracy: 86.33%
# Test Loss: 0.4010
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 85.86%
# Train Loss: 0.4744
# Test Accuracy: 80.00%
# Test Loss: 0.5042
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 82.71%
# Train Loss: 0.4818
# Test Accuracy: 80.00%
# Test Loss: 0.5068
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 62.86%
# Train Loss: 0.6580
# Test Accuracy: 64.33%
# Test Loss: 0.6473
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 42.71%
# Train Loss: 0.7333
# Test Accuracy: 43.00%
# Test Loss: 0.7336
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 73.00%
# Train Loss: 0.5653
# Test Accuracy: 69.00%
# Test Loss: 0.5875
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3179
# Test Accuracy: 84.67%
# Test Loss: 0.3748
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3091
# Test Accuracy: 84.67%
# Test Loss: 0.3788
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3079
# Test Accuracy: 85.00%
# Test Loss: 0.3839
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3096
# Test Accuracy: 85.00%
# Test Loss: 0.3926
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3071
# Test Accuracy: 84.67%
# Test Loss: 0.3793
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3072
# Test Accuracy: 85.00%
# Test Loss: 0.3828
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3070
# Test Accuracy: 84.67%
# Test Loss: 0.3806
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3076
# Test Accuracy: 85.00%
# Test Loss: 0.3830
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3069
# Test Accuracy: 85.00%
# Test Loss: 0.3816
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3070
# Test Accuracy: 85.00%
# Test Loss: 0.3811
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3069
# Test Accuracy: 84.67%
# Test Loss: 0.3809
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3080
# Test Accuracy: 84.67%
# Test Loss: 0.3764
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 85.71%
# Train Loss: 0.4060
# Test Accuracy: 80.00%
# Test Loss: 0.4517
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 83.57%
# Train Loss: 0.5373
# Test Accuracy: 79.67%
# Test Loss: 0.5588
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 74.14%
# Train Loss: 0.5963
# Test Accuracy: 69.00%
# Test Loss: 0.6079
#
# Training with 1 hidden layers, 4 neurons, ReLU activation, 250 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 78.71%
# Train Loss: 0.5187
# Test Accuracy: 75.33%
# Test Loss: 0.5295
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3106
# Test Accuracy: 85.67%
# Test Loss: 0.3888
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3098
# Test Accuracy: 85.67%
# Test Loss: 0.3749
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3078
# Test Accuracy: 84.33%
# Test Loss: 0.3836
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3091
# Test Accuracy: 85.33%
# Test Loss: 0.3894
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3076
# Test Accuracy: 85.00%
# Test Loss: 0.3858
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3074
# Test Accuracy: 85.67%
# Test Loss: 0.3828
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3072
# Test Accuracy: 84.33%
# Test Loss: 0.3824
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3082
# Test Accuracy: 84.67%
# Test Loss: 0.3775
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3614
# Test Accuracy: 85.00%
# Test Loss: 0.4044
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 85.29%
# Train Loss: 0.4170
# Test Accuracy: 81.00%
# Test Loss: 0.4611
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 76.29%
# Train Loss: 0.6051
# Test Accuracy: 72.33%
# Test Loss: 0.6151
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 66.14%
# Train Loss: 0.6446
# Test Accuracy: 59.67%
# Test Loss: 0.6618
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 47.71%
# Train Loss: 0.7450
# Test Accuracy: 45.67%
# Test Loss: 0.7410
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 72.00%
# Train Loss: 0.6019
# Test Accuracy: 66.00%
# Test Loss: 0.6085
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 50.14%
# Train Loss: 0.7828
# Test Accuracy: 50.67%
# Test Loss: 0.7646
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 50.43%
# Train Loss: 0.7057
# Test Accuracy: 47.33%
# Test Loss: 0.6999
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3122
# Test Accuracy: 85.00%
# Test Loss: 0.3863
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3106
# Test Accuracy: 87.33%
# Test Loss: 0.3792
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3077
# Test Accuracy: 85.33%
# Test Loss: 0.3780
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3115
# Test Accuracy: 85.00%
# Test Loss: 0.3735
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3074
# Test Accuracy: 85.67%
# Test Loss: 0.3785
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3076
# Test Accuracy: 84.67%
# Test Loss: 0.3806
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3070
# Test Accuracy: 84.33%
# Test Loss: 0.3819
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3078
# Test Accuracy: 84.33%
# Test Loss: 0.3773
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3088
# Test Accuracy: 84.67%
# Test Loss: 0.3774
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3668
# Test Accuracy: 85.67%
# Test Loss: 0.4064
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.4346
# Test Accuracy: 84.00%
# Test Loss: 0.4602
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 73.71%
# Train Loss: 0.5908
# Test Accuracy: 72.67%
# Test Loss: 0.6064
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 49.43%
# Train Loss: 0.7220
# Test Accuracy: 50.00%
# Test Loss: 0.7059
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 68.43%
# Train Loss: 0.6196
# Test Accuracy: 66.67%
# Test Loss: 0.6349
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 54.71%
# Train Loss: 0.6755
# Test Accuracy: 52.00%
# Test Loss: 0.6978
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 49.14%
# Train Loss: 0.7324
# Test Accuracy: 49.67%
# Test Loss: 0.7306
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3441
# Test Accuracy: 86.00%
# Test Loss: 0.4286
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3093
# Test Accuracy: 85.00%
# Test Loss: 0.3834
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3078
# Test Accuracy: 84.67%
# Test Loss: 0.3844
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3084
# Test Accuracy: 85.00%
# Test Loss: 0.3791
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3073
# Test Accuracy: 85.00%
# Test Loss: 0.3803
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3074
# Test Accuracy: 85.33%
# Test Loss: 0.3830
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3072
# Test Accuracy: 84.67%
# Test Loss: 0.3819
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3074
# Test Accuracy: 85.00%
# Test Loss: 0.3810
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3069
# Test Accuracy: 84.67%
# Test Loss: 0.3805
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3072
# Test Accuracy: 85.00%
# Test Loss: 0.3807
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3366
# Test Accuracy: 86.00%
# Test Loss: 0.3846
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.4369
# Test Accuracy: 84.00%
# Test Loss: 0.4663
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 81.71%
# Train Loss: 0.4813
# Test Accuracy: 79.33%
# Test Loss: 0.5020
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 59.71%
# Train Loss: 0.6645
# Test Accuracy: 61.67%
# Test Loss: 0.6688
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 63.00%
# Train Loss: 0.6336
# Test Accuracy: 63.33%
# Test Loss: 0.6423
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 50.71%
# Train Loss: 0.7474
# Test Accuracy: 48.33%
# Test Loss: 0.7756
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 87.86%
# Train Loss: 0.3284
# Test Accuracy: 86.33%
# Test Loss: 0.3833
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3130
# Test Accuracy: 84.67%
# Test Loss: 0.3934
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3086
# Test Accuracy: 85.00%
# Test Loss: 0.3906
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3107
# Test Accuracy: 87.00%
# Test Loss: 0.3752
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3071
# Test Accuracy: 84.67%
# Test Loss: 0.3849
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3075
# Test Accuracy: 85.33%
# Test Loss: 0.3854
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3070
# Test Accuracy: 85.00%
# Test Loss: 0.3806
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3073
# Test Accuracy: 85.00%
# Test Loss: 0.3794
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3069
# Test Accuracy: 85.00%
# Test Loss: 0.3812
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3070
# Test Accuracy: 85.00%
# Test Loss: 0.3816
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3069
# Test Accuracy: 85.00%
# Test Loss: 0.3811
#
# Training with 1 hidden layers, 4 neurons, Softmax activation, 250 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.43%
# ...
# Train Accuracy: 88.14%
# Train Loss: 0.3069
# Test Accuracy: 84.67%
# Test Loss: 0.3813
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3070
# Test Accuracy: 84.67%
# Test Loss: 0.3812
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3074
# Test Accuracy: 84.33%
# Test Loss: 0.3789
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3250
# Test Accuracy: 84.67%
# Test Loss: 0.3849
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3253
# Test Accuracy: 86.00%
# Test Loss: 0.3775
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3083
# Test Accuracy: 85.67%
# Test Loss: 0.3794
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3075
# Test Accuracy: 84.33%
# Test Loss: 0.3863
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3097
# Test Accuracy: 86.33%
# Test Loss: 0.3829
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3074
# Test Accuracy: 84.67%
# Test Loss: 0.3774
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3076
# Test Accuracy: 84.33%
# Test Loss: 0.3821
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3079
# Test Accuracy: 84.33%
# Test Loss: 0.3771
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3090
# Test Accuracy: 85.67%
# Test Loss: 0.3890
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3075
# Test Accuracy: 85.33%
# Test Loss: 0.3785
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3072
# Test Accuracy: 85.33%
# Test Loss: 0.3808
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3071
# Test Accuracy: 85.00%
# Test Loss: 0.3809
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3076
# Test Accuracy: 86.00%
# Test Loss: 0.3831
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3069
# Test Accuracy: 84.67%
# Test Loss: 0.3817
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3070
# Test Accuracy: 85.00%
# Test Loss: 0.3820
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3069
# Test Accuracy: 85.00%
# Test Loss: 0.3810
#
# Training with 3 hidden layers, 64 neurons, Softmax activation, 250 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3070
# Test Accuracy: 84.00%
# Test Loss: 0.3822
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3143
# Test Accuracy: 85.67%
# Test Loss: 0.3764
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3123
# Test Accuracy: 86.00%
# Test Loss: 0.3913
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 85.29%
# Train Loss: 0.5551
# Test Accuracy: 82.33%
# Test Loss: 0.7728
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 68.86%
# Train Loss: 14.6706
# Test Accuracy: 73.33%
# Test Loss: 12.5659
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3088
# Test Accuracy: 84.33%
# Test Loss: 0.3813
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3087
# Test Accuracy: 85.33%
# Test Loss: 0.3799
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3075
# Test Accuracy: 84.67%
# Test Loss: 0.3786
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 89.29%
# Train Loss: 0.3113
# Test Accuracy: 84.67%
# Test Loss: 0.4007
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3083
# Test Accuracy: 85.67%
# Test Loss: 0.3763
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3077
# Test Accuracy: 85.33%
# Test Loss: 0.3843
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3074
# Test Accuracy: 85.33%
# Test Loss: 0.3802
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3090
# Test Accuracy: 86.33%
# Test Loss: 0.3789
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3177
# Test Accuracy: 85.00%
# Test Loss: 0.3838
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 85.29%
# Train Loss: 0.4090
# Test Accuracy: 81.33%
# Test Loss: 0.4479
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 85.14%
# Train Loss: 0.5178
# Test Accuracy: 78.33%
# Test Loss: 0.5373
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 77.71%
# Train Loss: 0.5770
# Test Accuracy: 72.33%
# Test Loss: 0.5912
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3193
# Test Accuracy: 86.00%
# Test Loss: 0.4091
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3081
# Test Accuracy: 86.00%
# Test Loss: 0.3853
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3263
# Test Accuracy: 85.00%
# Test Loss: 0.4039
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 79.86%
# Train Loss: 0.5226
# Test Accuracy: 77.00%
# Test Loss: 0.6022
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3077
# Test Accuracy: 85.67%
# Test Loss: 0.3775
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3088
# Test Accuracy: 85.67%
# Test Loss: 0.3876
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3079
# Test Accuracy: 84.33%
# Test Loss: 0.3774
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3079
# Test Accuracy: 86.33%
# Test Loss: 0.3772
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3075
# Test Accuracy: 84.67%
# Test Loss: 0.3830
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3075
# Test Accuracy: 85.67%
# Test Loss: 0.3835
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3071
# Test Accuracy: 85.33%
# Test Loss: 0.3822
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3075
# Test Accuracy: 85.33%
# Test Loss: 0.3814
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3071
# Test Accuracy: 84.67%
# Test Loss: 0.3823
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3116
# Test Accuracy: 85.33%
# Test Loss: 0.3765
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 87.14%
# Train Loss: 0.3729
# Test Accuracy: 83.67%
# Test Loss: 0.4095
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 86.14%
# Train Loss: 0.4426
# Test Accuracy: 82.33%
# Test Loss: 0.4639
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3115
# Test Accuracy: 85.00%
# Test Loss: 0.3991
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3075
# Test Accuracy: 84.67%
# Test Loss: 0.3792
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3071
# Test Accuracy: 84.67%
# Test Loss: 0.3829
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3167
# Test Accuracy: 84.33%
# Test Loss: 0.3960
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3078
# Test Accuracy: 85.00%
# Test Loss: 0.3777
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3083
# Test Accuracy: 85.00%
# Test Loss: 0.3772
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3085
# Test Accuracy: 84.33%
# Test Loss: 0.3883
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3088
# Test Accuracy: 85.33%
# Test Loss: 0.3806
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3072
# Test Accuracy: 84.33%
# Test Loss: 0.3820
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.14%
# Train Loss: 0.3075
# Test Accuracy: 85.33%
# Test Loss: 0.3792
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3072
# Test Accuracy: 84.67%
# Test Loss: 0.3825
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3077
# Test Accuracy: 85.00%
# Test Loss: 0.3799
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3069
# Test Accuracy: 84.67%
# Test Loss: 0.3812
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3070
# Test Accuracy: 85.33%
# Test Loss: 0.3812
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 88.71%
# Train Loss: 0.3099
# Test Accuracy: 85.33%
# Test Loss: 0.3856
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3186
# Test Accuracy: 86.00%
# Test Loss: 0.3781
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3166
# Test Accuracy: 86.00%
# Test Loss: 0.3851
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 89.00%
# Train Loss: 0.3187
# Test Accuracy: 85.67%
# Test Loss: 0.3744
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3076
# Test Accuracy: 85.67%
# Test Loss: 0.3770
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3096
# Test Accuracy: 85.33%
# Test Loss: 0.3813
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 89.14%
# Train Loss: 0.3271
# Test Accuracy: 84.00%
# Test Loss: 0.4038
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3074
# Test Accuracy: 85.00%
# Test Loss: 0.3821
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3082
# Test Accuracy: 84.67%
# Test Loss: 0.3895
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 88.86%
# Train Loss: 0.3083
# Test Accuracy: 84.33%
# Test Loss: 0.3891
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3073
# Test Accuracy: 85.33%
# Test Loss: 0.3780
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 88.00%
# Train Loss: 0.3072
# Test Accuracy: 84.67%
# Test Loss: 0.3800
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3070
# Test Accuracy: 84.67%
# Test Loss: 0.3844
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 88.57%
# Train Loss: 0.3081
# Test Accuracy: 85.00%
# Test Loss: 0.3814
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3069
# Test Accuracy: 84.67%
# Test Loss: 0.3808
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 88.29%
# Train Loss: 0.3070
# Test Accuracy: 84.67%
# Test Loss: 0.3822
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3069
# Test Accuracy: 85.33%
# Test Loss: 0.3813
#
# Training with 3 hidden layers, 64 neurons, Tanh activation, 250 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 88.43%
# Train Loss: 0.3070
# Test Accuracy: 85.00%
# Test Loss: 0.3814

# %%
# Menampilkan Konfigurasi Hyperparameter Terbaik dan Terburuk
print("\nBest Hyperparameter Configuration (Overall):")
print(f"Hidden Layers: {best_result['Hyperparameters']['Hidden Layers']}")
print(f"Hidden Neurons: {best_result['Hyperparameters']['Hidden Neurons']}")
print(f"Activation Function: {best_result['Hyperparameters']['Activation Function']}")
print(f"Epochs: {best_result['Hyperparameters']['Epochs']}")
print(f"Learning Rate: {best_result['Hyperparameters']['Learning Rate']}")
print(f"Batch Size: {best_result['Hyperparameters']['Batch Size']}")
print(f"Test Accuracy: {best_result['Test Accuracy'] * 100:.2f}%")

print("\nWorst Hyperparameter Configuration:")
print(f"Hidden Layers: {worst_result['Hyperparameters']['Hidden Layers']}")
print(f"Hidden Neurons: {worst_result['Hyperparameters']['Hidden Neurons']}")
print(f"Activation Function: {worst_result['Hyperparameters']['Activation Function']}")
print(f"Epochs: {worst_result['Hyperparameters']['Epochs']}")
print(f"Learning Rate: {worst_result['Hyperparameters']['Learning Rate']}")
print(f"Batch Size: {worst_result['Hyperparameters']['Batch Size']}")
print(f"Test Accuracy: {worst_result['Test Accuracy'] * 100:.2f}%")

# Menampilkan Konfigurasi Terbaik untuk Setiap Fungsi Aktivasin
for activation in activation_functions:
    print(f"\nBest Configuration for Activation Function {activation}:")
    if best_per_activation[activation]:
        print(f"Hidden Layers: {best_per_activation[activation]['Hyperparameters']['Hidden Layers']}")
        print(f"Hidden Neurons: {best_per_activation[activation]['Hyperparameters']['Hidden Neurons']}")
        print(f"Activation Function: {activation}")
        print(f"Epochs: {best_per_activation[activation]['Hyperparameters']['Epochs']}")
        print(f"Learning Rate: {best_per_activation[activation]['Hyperparameters']['Learning Rate']}")
        print(f"Batch Size: {best_per_activation[activation]['Hyperparameters']['Batch Size']}")
        print(f"Test Accuracy: {best_per_activation[activation]['Test Accuracy'] * 100:.2f}%")
    else:
        print("No result for this activation function.")
# Out:
# Best Hyperparameter Configuration (Overall):
# Hidden Layers: 1
# Hidden Neurons: 4
# Activation Function: Softmax
# Epochs: 50
# Learning Rate: 0.1
# Batch Size: 128
# Test Accuracy: 87.33%
#
# Worst Hyperparameter Configuration:
# Hidden Layers: 1
# Hidden Neurons: 64
# Activation Function: linear
# Epochs: 25
# Learning Rate: 0.0001
# Batch Size: 512
# Test Accuracy: 28.33%
#
# Best Configuration for Activation Function linear:
# Hidden Layers: 3
# Hidden Neurons: 8
# Activation Function: linear
# Epochs: 250
# Learning Rate: 0.1
# Batch Size: 64
# Test Accuracy: 87.33%
#
# Best Configuration for Activation Function Sigmoid:
# Hidden Layers: 1
# Hidden Neurons: 8
# Activation Function: Sigmoid
# Epochs: 25
# Learning Rate: 0.1
# Batch Size: 256
# Test Accuracy: 87.00%
#
# Best Configuration for Activation Function ReLU:
# Hidden Layers: 3
# Hidden Neurons: 4
# Activation Function: ReLU
# Epochs: 250
# Learning Rate: 0.1
# Batch Size: 64
# Test Accuracy: 87.00%
#
# Best Configuration for Activation Function Softmax:
# Hidden Layers: 1
# Hidden Neurons: 4
# Activation Function: Softmax
# Epochs: 50
# Learning Rate: 0.1
# Batch Size: 128
# Test Accuracy: 87.33%
#
# Best Configuration for Activation Function Tanh:
# Hidden Layers: 1
# Hidden Neurons: 32
# Activation Function: Tanh
# Epochs: 25
# Learning Rate: 0.01
# Batch Size: 512
# Test Accuracy: 87.33%

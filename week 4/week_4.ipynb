# %% [markdown]
# <a href="https://colab.research.google.com/github/gopaps/MachineLearning/blob/main/week%204/week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data manipulation libraries
import numpy as np
import pandas as pd

#Data Visulaization Libraries
import matplotlib.pyplot as plt
import seaborn as sns
#To ensure that plots are displayed inline in jupyter notebook
# %matplotlib inline

# %%
#Menghubungkan Google Colab dengan Google Drive
from google.colab import drive
#Mount Google Drive ke Colab
drive.mount('/content/drive')
#Setelah ini, kamu bisa mengakses file di Google Drive melalui path '/content/drive/My Drive/'
# Out:
# Mounted at /content/drive

# %%
#Memuat dataset dari Google Drive
import pandas as pd
#Path ke file dataset di Google Drive
file_path='/content/drive/My Drive/dataset/StudentsPerformance.csv'
#Memuat dataset ke dalam DataFrame pandas
df = pd.read_csv(file_path)
#Menampilkan beberapa baris pertama dari dataset
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#Melihat shape dari DataFrame
print(df.shape)
# Out:
# (1000, 8)

# %%
# Melihat statistical summary dari DataFrame
print(df.describe())
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %%
# Set the plot style
sns.set(style="whitegrid")

# %%
# 1. Visualisasi Distribusi Gender
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="gender", palette="pastel")
plt.title('Distribution of Gender in Dataset')
plt.show()
# Out:
# <ipython-input-18-9bc7164d2010>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="gender", palette="pastel")

# %%
# 2. Visualisasi Distribusi Nilai Matematika
plt.figure(figsize=(8,5))
sns.histplot(df['math score'], kde=True, color='skyblue')
plt.title('Distribution of Math Scores')
plt.show()

# %%
# 3. Visualisasi Distribusi Nilai Membaca
plt.figure(figsize=(8,5))
sns.histplot(df['reading score'], kde=True, color='lightgreen')
plt.title('Distribution of Reading Scores')
plt.show()

# %%
# 4. Visualisasi Distribusi Nilai Menulis
plt.figure(figsize=(8,5))
sns.histplot(df['writing score'], kde=True, color='salmon')
plt.title('Distribution of Writing Scores')
plt.show()

# %%
# 5. Visualisasi Performa Berdasarkan Race/Ethnicity
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="race/ethnicity", y="math score", palette="Set3")
plt.title('Math Score by Race/Ethnicity')
plt.show()
# Out:
# <ipython-input-22-4b4e6f31cf1a>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="race/ethnicity", y="math score", palette="Set3")

# %%
# 6. Visualisasi Performa Berdasarkan Parental Level of Education
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x="parental level of education", y="math score", palette="Set2")
plt.title('Math Score by Parental Level of Education')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-23-3387e4aeb994>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="parental level of education", y="math score", palette="Set2")

# %%
# 7. Visualisasi Pengaruh Kursus Persiapan Tes Terhadap Skor Matematika
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="test preparation course", y="math score", palette="muted")
plt.title('Math Score by Test Preparation Course')
plt.show()
# Out:
# <ipython-input-24-40bb0cadbac4>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="test preparation course", y="math score", palette="muted")

# %%
# Rename kolom dataset
df.rename(columns={
    'gender': 'gender',
    'race/ethnicity': 'race/ethnicity',
    'parental level of education': 'parental level of education',
    'lunch': 'lunch',
    'test preparation course': 'test preparation course',
    'math score': 'math score',
    'reading score': 'reading score',
    'writing score': 'writing score'
}, inplace=True)

# Menampilkan nama kolom setelah diubah
print(df.columns)
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# Klasifikasi kolom berdasarkan tipe data
categorical_columns = df.select_dtypes(include=['object']).columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Menampilkan hasil klasifikasi kolom
print("Categorical Columns:")
print(categorical_columns)

print("\nNumerical Columns:")
print(numerical_columns)
# Out:
# Categorical Columns:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')
#
# Numerical Columns:
# Index(['math score', 'reading score', 'writing score'], dtype='object')

# %%
#Memerikasa apakah ada null di dataset
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Menghitung total skor dari Math, Reading, dan Writing untuk setiap siswa
df['total score'] = df['math score'] + df['reading score'] + df['writing score']

# %%
# 1. Rata-rata Total Skor Berdasarkan Gender
plt.figure(figsize=(8,6))
sns.barplot(data=df, x="gender", y="total score", palette="Set2")
plt.title('Average Total Score by Gender')
plt.show()
# Out:
# <ipython-input-29-9d055c47de89>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="gender", y="total score", palette="Set2")

# %%
# 2. Rata-rata Total Skor Berdasarkan Race/Ethnicity
plt.figure(figsize=(8,6))
sns.barplot(data=df, x="race/ethnicity", y="total score", palette="Set3")
plt.title('Average Total Score by Race/Ethnicity')
plt.show()
# Out:
# <ipython-input-30-f3055daf8509>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="race/ethnicity", y="total score", palette="Set3")

# %%
# 3. Rata-rata Total Skor Berdasarkan Parental Level of Education
plt.figure(figsize=(10,6))
sns.barplot(data=df, x="parental level of education", y="total score", palette="muted")
plt.title('Average Total Score by Parental Level of Education')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-31-6fd2ce447e72>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="parental level of education", y="total score", palette="muted")

# %%
# 4. Rata-rata Total Skor Berdasarkan Test Preparation Course
plt.figure(figsize=(8,6))
sns.barplot(data=df, x="test preparation course", y="total score", palette="Set1")
plt.title('Average Total Score by Test Preparation Course')
plt.show()
# Out:
# <ipython-input-32-eab99755fa15>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="test preparation course", y="total score", palette="Set1")

# %%
#Memuat dataset dari Google Drive
import pandas as pd
#Path ke file dataset di Google Drive
file_path='/content/drive/My Drive/dataset/StudentsPerformance.csv'
#Memuat dataset ke dalam DataFrame pandas
df = pd.read_csv(file_path)
#Menampilkan beberapa baris pertama dari dataset
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Mengimpor modul yang diperlukan
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Menghubungkan Google Drive ke Colab
from google.colab import drive
drive.mount('/content/drive')

# Path ke file dataset di Google Drive
file_path = '/content/drive/My Drive/dataset/StudentsPerformance.csv'

# Memuat dataset ke dalam DataFrame pandas
df = pd.read_csv(file_path)

# Menampilkan beberapa baris pertama dari dataset
df.head()

# Menambahkan kolom baru untuk rata-rata nilai
df['average_score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

# Menampilkan rata-rata nilai dari seluruh siswa
print("Rata-rata nilai seluruh mata pelajaran dari setiap siswa:")
print(df[['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'average_score']].head())

# Visualisasi korelasi rata-rata nilai dengan kategori menggunakan boxplot
plt.figure(figsize=(15, 10))

# Korelasi dengan gender
plt.subplot(3, 2, 1)
sns.boxplot(x='gender', y='average_score', data=df, palette="pastel")
plt.title("Average Score by Gender")

# Korelasi dengan race/ethnicity
plt.subplot(3, 2, 2)
sns.boxplot(x='race/ethnicity', y='average_score', data=df, palette="Set3")
plt.title("Average Score by Race/Ethnicity")

# Korelasi dengan parental level of education
plt.subplot(3, 2, 3)
sns.boxplot(x='parental level of education', y='average_score', data=df, palette="pastel")
plt.xticks(rotation=45)
plt.title("Average Score by Parental Level of Education")

# Korelasi dengan lunch
plt.subplot(3, 2, 4)
sns.boxplot(x='lunch', y='average_score', data=df, palette="Blues")
plt.title("Average Score by Lunch")

# Korelasi dengan test preparation course
plt.subplot(3, 2, 5)
sns.boxplot(x='test preparation course', y='average_score', data=df, palette="Purples")
plt.title("Average Score by Test Preparation Course")

plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive
# Rata-rata nilai seluruh mata pelajaran dari setiap siswa:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  average_score
# 0                    none      72.666667
# 1               completed      82.333333
# 2                    none      92.666667
# 3                    none      49.333333
# 4                    none      76.333333
# <ipython-input-4-b7411332f018>:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='average_score', data=df, palette="pastel")
# <ipython-input-4-b7411332f018>:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='race/ethnicity', y='average_score', data=df, palette="Set3")
# <ipython-input-4-b7411332f018>:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='parental level of education', y='average_score', data=df, palette="pastel")
# <ipython-input-4-b7411332f018>:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='lunch', y='average_score', data=df, palette="Blues")
# <ipython-input-4-b7411332f018>:52: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='test preparation course', y='average_score', data=df, palette="Purples")

# %%
# Mengatur ukuran dan gaya visualisasi
plt.figure(figsize=(15, 10))
sns.set_style("whitegrid")

# Membuat plot untuk pengaruh `gender` terhadap nilai
plt.subplot(3, 3, 1)
sns.boxplot(x='gender', y='math score', data=df, palette="pastel")
plt.title("Math Score by Gender")

plt.subplot(3, 3, 2)
sns.boxplot(x='gender', y='reading score', data=df, palette="pastel")
plt.title("Reading Score by Gender")

plt.subplot(3, 3, 3)
sns.boxplot(x='gender', y='writing score', data=df, palette="pastel")
plt.title("Writing Score by Gender")

# Membuat plot untuk pengaruh `race/ethnicity` terhadap nilai
plt.subplot(3, 3, 4)
sns.boxplot(x='race/ethnicity', y='math score', data=df, palette="Set3")
plt.title("Math Score by Race/Ethnicity")

plt.subplot(3, 3, 5)
sns.boxplot(x='race/ethnicity', y='reading score', data=df, palette="Set3")
plt.title("Reading Score by Race/Ethnicity")

plt.subplot(3, 3, 6)
sns.boxplot(x='race/ethnicity', y='writing score', data=df, palette="Set3")
plt.title("Writing Score by Race/Ethnicity")

# Membuat plot untuk pengaruh `parental level of education` terhadap nilai
plt.subplot(3, 3, 7)
sns.boxplot(x='parental level of education', y='math score', data=df, palette="pastel")
plt.xticks(rotation=45)
plt.title("Math Score by Parental Level of Education")

plt.subplot(3, 3, 8)
sns.boxplot(x='parental level of education', y='reading score', data=df, palette="pastel")
plt.xticks(rotation=45)
plt.title("Reading Score by Parental Level of Education")

plt.subplot(3, 3, 9)
sns.boxplot(x='parental level of education', y='writing score', data=df, palette="pastel")
plt.xticks(rotation=45)
plt.title("Writing Score by Parental Level of Education")

plt.tight_layout()
plt.show()

# Visualisasi tambahan untuk `lunch` dan `test preparation course`
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

sns.boxplot(ax=axes[0, 0], x='lunch', y='math score', data=df, palette="Blues")
axes[0, 0].set_title("Math Score by Lunch")

sns.boxplot(ax=axes[0, 1], x='lunch', y='reading score', data=df, palette="Blues")
axes[0, 1].set_title("Reading Score by Lunch")

sns.boxplot(ax=axes[0, 2], x='lunch', y='writing score', data=df, palette="Blues")
axes[0, 2].set_title("Writing Score by Lunch")

sns.boxplot(ax=axes[1, 0], x='test preparation course', y='math score', data=df, palette="Purples")
axes[1, 0].set_title("Math Score by Test Preparation Course")

sns.boxplot(ax=axes[1, 1], x='test preparation course', y='reading score', data=df, palette="Purples")
axes[1, 1].set_title("Reading Score by Test Preparation Course")

sns.boxplot(ax=axes[1, 2], x='test preparation course', y='writing score', data=df, palette="Purples")
axes[1, 2].set_title("Writing Score by Test Preparation Course")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-ca55bfae50c1>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='math score', data=df, palette="pastel")
# <ipython-input-5-ca55bfae50c1>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='reading score', data=df, palette="pastel")
# <ipython-input-5-ca55bfae50c1>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='writing score', data=df, palette="pastel")
# <ipython-input-5-ca55bfae50c1>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='race/ethnicity', y='math score', data=df, palette="Set3")
# <ipython-input-5-ca55bfae50c1>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='race/ethnicity', y='reading score', data=df, palette="Set3")
# <ipython-input-5-ca55bfae50c1>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='race/ethnicity', y='writing score', data=df, palette="Set3")
# <ipython-input-5-ca55bfae50c1>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='parental level of education', y='math score', data=df, palette="pastel")
# <ipython-input-5-ca55bfae50c1>:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='parental level of education', y='reading score', data=df, palette="pastel")
# <ipython-input-5-ca55bfae50c1>:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='parental level of education', y='writing score', data=df, palette="pastel")
# <ipython-input-5-ca55bfae50c1>:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[0, 0], x='lunch', y='math score', data=df, palette="Blues")
# <ipython-input-5-ca55bfae50c1>:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[0, 1], x='lunch', y='reading score', data=df, palette="Blues")
# <ipython-input-5-ca55bfae50c1>:59: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[0, 2], x='lunch', y='writing score', data=df, palette="Blues")
# <ipython-input-5-ca55bfae50c1>:62: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[1, 0], x='test preparation course', y='math score', data=df, palette="Purples")
# <ipython-input-5-ca55bfae50c1>:65: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[1, 1], x='test preparation course', y='reading score', data=df, palette="Purples")
# <ipython-input-5-ca55bfae50c1>:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[1, 2], x='test preparation course', y='writing score', data=df, palette="Purples")

# %%
# Menambahkan kolom baru untuk status kelulusan (Pass atau Fail) pada setiap mata pelajaran
df['math_status'] = df['math score'].apply(lambda x: 'Pass' if x >= 75 else 'Fail')
df['reading_status'] = df['reading score'].apply(lambda x: 'Pass' if x >= 75 else 'Fail')
df['writing_status'] = df['writing score'].apply(lambda x: 'Pass' if x >= 75 else 'Fail')

# Menghitung jumlah siswa yang Pass dan Fail untuk masing-masing pelajaran
math_counts = df['math_status'].value_counts()
reading_counts = df['reading_status'].value_counts()
writing_counts = df['writing_status'].value_counts()

# Menampilkan hasil
print("Math Pass/Fail Counts:")
print(math_counts)
print("\nReading Pass/Fail Counts:")
print(reading_counts)
print("\nWriting Pass/Fail Counts:")
print(writing_counts)
# Out:
# Math Pass/Fail Counts:
# math_status
# Fail    705
# Pass    295
# Name: count, dtype: int64
#
# Reading Pass/Fail Counts:
# reading_status
# Fail    630
# Pass    370
# Name: count, dtype: int64
#
# Writing Pass/Fail Counts:
# writing_status
# Fail    650
# Pass    350
# Name: count, dtype: int64

# %%
# Mengatur ukuran dan gaya visualisasi
plt.figure(figsize=(15, 5))
sns.set_style("whitegrid")

# Plot Histogram untuk Distribusi Math Score
plt.subplot(1, 3, 1)
sns.histplot(df['math score'], bins=20, kde=True, color="skyblue")
plt.title('Distribution of Math Scores')
plt.xlabel('Math Score')
plt.ylabel('Frequency')

# Plot Histogram untuk Distribusi Reading Score
plt.subplot(1, 3, 2)
sns.histplot(df['reading score'], bins=20, kde=True, color="lightcoral")
plt.title('Distribution of Reading Scores')
plt.xlabel('Reading Score')
plt.ylabel('Frequency')

# Plot Histogram untuk Distribusi Writing Score
plt.subplot(1, 3, 3)
sns.histplot(df['writing score'], bins=20, kde=True, color="lightgreen")
plt.title('Distribution of Writing Scores')
plt.xlabel('Writing Score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Menggunakan Boxplot untuk melihat distribusi nilai secara lebih mendetail
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.boxplot(y=df['math score'], color="skyblue")
plt.title('Math Score Distribution')

plt.subplot(1, 3, 2)
sns.boxplot(y=df['reading score'], color="lightcoral")
plt.title('Reading Score Distribution')

plt.subplot(1, 3, 3)
sns.boxplot(y=df['writing score'], color="lightgreen")
plt.title('Writing Score Distribution')

plt.tight_layout()
plt.show()

# %%
def plot_pie_chart(column_name, color_map='Pastel1'):
    data = df[column_name].value_counts()
    labels = data.index
    sizes = data.values

    plt.figure(figsize=(7, 7))
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.get_cmap(color_map).colors)
    plt.axis('equal')  # Untuk memastikan pie chart berbentuk lingkaran
    plt.title(f'Percentage of {column_name}', fontsize=14, color='darkblue')
    plt.show()

# Menggunakan palet warna pastel
plot_pie_chart('gender', 'Pastel1')
plot_pie_chart('race/ethnicity', 'Pastel2')
plot_pie_chart('lunch', 'Pastel1')
plot_pie_chart('parental level of education', 'Pastel2')
plot_pie_chart('test preparation course', 'Pastel1')
# Out:
# <ipython-input-9-e557ed1b0f78>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.get_cmap(color_map).colors)
# <ipython-input-9-e557ed1b0f78>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.get_cmap(color_map).colors)
# <ipython-input-9-e557ed1b0f78>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.get_cmap(color_map).colors)
# <ipython-input-9-e557ed1b0f78>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.get_cmap(color_map).colors)
# <ipython-input-9-e557ed1b0f78>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.get_cmap(color_map).colors)

# %%
# Mengatur ukuran dan gaya untuk semua plot
plt.figure(figsize=(15, 10))
sns.set_style("whitegrid")

# Membuat plot untuk pengaruh `gender` terhadap nilai
plt.subplot(2, 3, 1)
sns.boxplot(x='gender', y='math score', data=df, palette="Wistia")
plt.title("Math Score by Gender")

plt.subplot(2, 3, 2)
sns.boxplot(x='gender', y='reading score', data=df, palette="Wistia")
plt.title("Reading Score by Gender")

plt.subplot(2, 3, 3)
sns.boxplot(x='gender', y='writing score', data=df, palette="Wistia")
plt.title("Writing Score by Gender")

# Membuat plot untuk pengaruh `race/ethnicity` terhadap nilai
plt.subplot(2, 3, 4)
sns.boxplot(x='race/ethnicity', y='math score', data=df, palette="OrRd")
plt.title("Math Score by Race/Ethnicity")

plt.subplot(2, 3, 5)
sns.boxplot(x='race/ethnicity', y='reading score', data=df, palette="OrRd")
plt.title("Reading Score by Race/Ethnicity")

plt.subplot(2, 3, 6)
sns.boxplot(x='race/ethnicity', y='writing score', data=df, palette="OrRd")
plt.title("Writing Score by Race/Ethnicity")

plt.tight_layout()
plt.show()

# Plot tambahan untuk `parental level of education`, `lunch`, dan `test preparation course`
fig, axes = plt.subplots(3, 3, figsize=(18, 12))

# Parental level of education
sns.boxplot(ax=axes[0, 0], x='parental level of education', y='math score', data=df, palette="YlOrBr")
axes[0, 0].set_title("Math Score by Parental Level of Education")
sns.boxplot(ax=axes[0, 1], x='parental level of education', y='reading score', data=df, palette="YlOrBr")
axes[0, 1].set_title("Reading Score by Parental Level of Education")
sns.boxplot(ax=axes[0, 2], x='parental level of education', y='writing score', data=df, palette="YlOrBr")
axes[0, 2].set_title("Writing Score by Parental Level of Education")

# Lunch
sns.boxplot(ax=axes[1, 0], x='lunch', y='math score', data=df, palette="YlGnBu")
axes[1, 0].set_title("Math Score by Lunch")
sns.boxplot(ax=axes[1, 1], x='lunch', y='reading score', data=df, palette="YlGnBu")
axes[1, 1].set_title("Reading Score by Lunch")
sns.boxplot(ax=axes[1, 2], x='lunch', y='writing score', data=df, palette="YlGnBu")
axes[1, 2].set_title("Writing Score by Lunch")

# Test preparation course
sns.boxplot(ax=axes[2, 0], x='test preparation course', y='math score', data=df, palette="BuPu")
axes[2, 0].set_title("Math Score by Test Preparation Course")
sns.boxplot(ax=axes[2, 1], x='test preparation course', y='reading score', data=df, palette="BuPu")
axes[2, 1].set_title("Reading Score by Test Preparation Course")
sns.boxplot(ax=axes[2, 2], x='test preparation course', y='writing score', data=df, palette="BuPu")
axes[2, 2].set_title("Writing Score by Test Preparation Course")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-dc6b84803af2>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='math score', data=df, palette="Wistia")
# <ipython-input-10-dc6b84803af2>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='reading score', data=df, palette="Wistia")
# <ipython-input-10-dc6b84803af2>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='writing score', data=df, palette="Wistia")
# <ipython-input-10-dc6b84803af2>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='race/ethnicity', y='math score', data=df, palette="OrRd")
# <ipython-input-10-dc6b84803af2>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='race/ethnicity', y='reading score', data=df, palette="OrRd")
# <ipython-input-10-dc6b84803af2>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='race/ethnicity', y='writing score', data=df, palette="OrRd")
# <ipython-input-10-dc6b84803af2>:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[0, 0], x='parental level of education', y='math score', data=df, palette="YlOrBr")
# <ipython-input-10-dc6b84803af2>:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[0, 1], x='parental level of education', y='reading score', data=df, palette="YlOrBr")
# <ipython-input-10-dc6b84803af2>:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[0, 2], x='parental level of education', y='writing score', data=df, palette="YlOrBr")
# <ipython-input-10-dc6b84803af2>:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[1, 0], x='lunch', y='math score', data=df, palette="YlGnBu")
# <ipython-input-10-dc6b84803af2>:48: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[1, 1], x='lunch', y='reading score', data=df, palette="YlGnBu")
# <ipython-input-10-dc6b84803af2>:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[1, 2], x='lunch', y='writing score', data=df, palette="YlGnBu")
# <ipython-input-10-dc6b84803af2>:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[2, 0], x='test preparation course', y='math score', data=df, palette="BuPu")
# <ipython-input-10-dc6b84803af2>:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[2, 1], x='test preparation course', y='reading score', data=df, palette="BuPu")
# <ipython-input-10-dc6b84803af2>:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[2, 2], x='test preparation course', y='writing score', data=df, palette="BuPu")

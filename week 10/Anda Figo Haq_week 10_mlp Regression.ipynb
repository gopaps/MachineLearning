# %% [markdown]
# Regression Model: MLP Regression: winequality-white.csv

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
import pandas as pd
import numpy as np

# %%
# Membaca dataset dengan delimiter yang benar (;)
data = pd.read_csv('winequality-white.csv', delimiter=';')

# Menampilkan beberapa baris pertama untuk memastikan data terbaca dengan benar
print(data.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
# Menampilkan beberapa baris pertama untuk melihat data secara umum
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
X = data.iloc[:, :-1].values  # Fitur (semua kolom kecuali 'quality')
y = data.iloc[:, -1].values  # Target (kolom 'quality')

# %%
# Normalize features and target
X = (X - X.mean(axis=0)) / X.std(axis=0)  # Normalisasi fitur (mean=0, std=1)
y = (y - y.mean()) / y.std()  # Normalisasi target untuk regresi

# %%
# PyTorch Dataset class untuk menangani data
class WineDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)  # Konversi fitur ke tensor PyTorch
        self.y = torch.tensor(y, dtype=torch.float32)  # Konversi target ke tensor PyTorch

    def __len__(self):
        return len(self.X)  # Mengembalikan jumlah data

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]  # Mengembalikan pasangan fitur dan target

# %%
# Buat dataset PyTorch
dataset = WineDataset(X, y)

# %%
# Split dataset menjadi 80% training dan 20% testing
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
# Definisi model MLP (Multilayer Perceptron)
class MLPRegressor(nn.Module):
    def __init__(self, input_size, hidden_layers, activation_fn):
        super(MLPRegressor, self).__init__()
        layers = []
        in_features = input_size  # Input size (jumlah fitur)
        for neurons in hidden_layers:
            layers.append(nn.Linear(in_features, neurons))  # Tambahkan layer linear
            layers.append(activation_fn)  # Tambahkan fungsi aktivasi
            in_features = neurons  # Update jumlah neuron untuk layer berikutnya
        layers.append(nn.Linear(in_features, 1))  # Output layer (satu neuron untuk regresi)
        self.model = nn.Sequential(*layers)  # Gabungkan semua layer menjadi satu model

    def forward(self, x):
        return self.model(x)  # Forward pass (prediksi)

# %%
# Parameter eksperimen yang akan diuji
hidden_layer_configs = [[4], [8], [16], [32], [64], [4, 8], [8, 16], [16, 32], [32, 64], [4, 8, 16]]  # Kombinasi jumlah neuron
activation_functions = {'linear': nn.Identity(), 'sigmoid': nn.Sigmoid(), 'relu': nn.ReLU(), 'softmax': nn.Softmax(dim=-1), 'tanh': nn.Tanh()}  # Fungsi aktivasi
epochs_list = [1, 10, 25, 50, 100, 250]  # Jumlah epoch
learning_rates = [10, 1, 0.1, 0.01, 0.001, 0.0001]  # Learning rate
batch_sizes = [16, 32, 64, 128, 256, 512]  # Ukuran batch

# %%
# Untuk menyimpan hasil
results = []

# %%
# Gunakan GPU jika tersedia, jika tidak gunakan CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Loop untuk menguji semua kombinasi parameter
for hidden_layers in hidden_layer_configs:
    for act_name, activation_fn in activation_functions.items():
        for epochs in epochs_list:
            for lr in learning_rates:
                for batch_size in batch_sizes:
                    # Buat DataLoader untuk batching data
                    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
                    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

                    # Buat model, loss function, dan optimizer
                    model = MLPRegressor(X.shape[1], hidden_layers, activation_fn).to(device)  # Model MLP
                    criterion = nn.MSELoss()  # Mean Squared Error untuk regresi
                    optimizer = optim.Adam(model.parameters(), lr=lr)  # Optimizer Adam

                    # Training loop
                    model.train()
                    for epoch in range(epochs):
                        for inputs, targets in train_loader:
                            inputs, targets = inputs.to(device), targets.to(device)  # Pindahkan data ke GPU/CPU
                            optimizer.zero_grad()  # Reset gradien
                            outputs = model(inputs).squeeze()  # Forward pass
                            loss = criterion(outputs, targets)  # Hitung loss
                            loss.backward()  # Backpropagation
                            optimizer.step()  # Update bobot model

                    # Evaluation (uji model)
                    model.eval()
                    test_loss = 0
                    with torch.no_grad():  # Nonaktifkan gradien selama evaluasi
                        for inputs, targets in test_loader:
                            inputs, targets = inputs.to(device), targets.to(device)
                            outputs = model(inputs).squeeze()
                            test_loss += criterion(outputs, targets).item()  # Hitung loss untuk data uji

                    test_loss /= len(test_loader)  # Rata-rata loss
                    # Simpan hasil
                    results.append((hidden_layers, act_name, epochs, lr, batch_size, test_loss))
                    print(f"Hidden Layers: {hidden_layers}, Activation: {act_name}, Epochs: {epochs}, LR: {lr}, Batch Size: {batch_size}, Test Loss: {test_loss:.4f}")
# Out:
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 10, Batch Size: 16, Test Loss: 0.9893
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 10, Batch Size: 32, Test Loss: 7.5991
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 10, Batch Size: 64, Test Loss: 1469.8445
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 10, Batch Size: 128, Test Loss: 32806.3987
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 10, Batch Size: 256, Test Loss: 349638.9766
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 10, Batch Size: 512, Test Loss: 64887.4238
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 1, Batch Size: 16, Test Loss: 1.4849
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 1, Batch Size: 32, Test Loss: 0.7674
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 1, Batch Size: 64, Test Loss: 0.8740
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 1, Batch Size: 128, Test Loss: 8.6480
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 1, Batch Size: 256, Test Loss: 27.6898
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 1, Batch Size: 512, Test Loss: 50.2703
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.1, Batch Size: 16, Test Loss: 0.7863
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.1, Batch Size: 32, Test Loss: 0.8512
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.1, Batch Size: 64, Test Loss: 0.7685
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.1, Batch Size: 128, Test Loss: 0.7686
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.1, Batch Size: 256, Test Loss: 0.7574
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.1, Batch Size: 512, Test Loss: 0.7890
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.01, Batch Size: 16, Test Loss: 0.7532
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.01, Batch Size: 32, Test Loss: 0.7541
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.01, Batch Size: 64, Test Loss: 0.7406
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.01, Batch Size: 128, Test Loss: 0.7743
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.01, Batch Size: 256, Test Loss: 0.7871
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.01, Batch Size: 512, Test Loss: 1.0514
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.001, Batch Size: 16, Test Loss: 0.8475
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.001, Batch Size: 32, Test Loss: 0.8568
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.001, Batch Size: 64, Test Loss: 0.9274
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.001, Batch Size: 128, Test Loss: 1.0429
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.001, Batch Size: 256, Test Loss: 1.2865
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.001, Batch Size: 512, Test Loss: 1.0793
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.0001, Batch Size: 16, Test Loss: 1.0201
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.0001, Batch Size: 32, Test Loss: 1.3765
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.0001, Batch Size: 64, Test Loss: 1.3475
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.0001, Batch Size: 128, Test Loss: 1.6867
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.0001, Batch Size: 256, Test Loss: 1.1624
# Hidden Layers: [4], Activation: linear, Epochs: 1, LR: 0.0001, Batch Size: 512, Test Loss: 1.1266
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 10, Batch Size: 16, Test Loss: 1.5582
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 10, Batch Size: 32, Test Loss: 0.9945
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 10, Batch Size: 64, Test Loss: 0.9152
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 10, Batch Size: 128, Test Loss: 1.2710
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 10, Batch Size: 256, Test Loss: 0.9962
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 10, Batch Size: 512, Test Loss: 288.6553
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 1, Batch Size: 16, Test Loss: 0.9467
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 1, Batch Size: 32, Test Loss: 1.1591
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 1, Batch Size: 64, Test Loss: 0.7605
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 1, Batch Size: 128, Test Loss: 0.7585
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 1, Batch Size: 256, Test Loss: 0.9670
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 1, Batch Size: 512, Test Loss: 0.7959
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.1, Batch Size: 16, Test Loss: 0.8382
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.1, Batch Size: 32, Test Loss: 0.7720
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.1, Batch Size: 64, Test Loss: 0.7907
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.1, Batch Size: 128, Test Loss: 0.7588
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.1, Batch Size: 256, Test Loss: 0.7525
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.1, Batch Size: 512, Test Loss: 0.7515
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.7577
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.7521
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.7391
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 128, Test Loss: 0.7479
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 256, Test Loss: 0.7464
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 512, Test Loss: 0.7521
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.7475
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.7500
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.7447
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 128, Test Loss: 0.7690
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 256, Test Loss: 0.7985
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 512, Test Loss: 0.9073
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.8631
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.8397
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.8726
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 128, Test Loss: 1.1255
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 256, Test Loss: 0.9385
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 512, Test Loss: 1.4388
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 10, Batch Size: 16, Test Loss: 1.0336
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 10, Batch Size: 32, Test Loss: 1.9567
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 10, Batch Size: 64, Test Loss: 2.2472
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 10, Batch Size: 128, Test Loss: 0.7684
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 10, Batch Size: 256, Test Loss: 1.0996
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 10, Batch Size: 512, Test Loss: 0.7867
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 1, Batch Size: 16, Test Loss: 1.1282
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 1, Batch Size: 32, Test Loss: 1.0002
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 1, Batch Size: 64, Test Loss: 0.9350
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 1, Batch Size: 128, Test Loss: 0.7748
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 1, Batch Size: 256, Test Loss: 0.7557
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 1, Batch Size: 512, Test Loss: 0.8016
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.1, Batch Size: 16, Test Loss: 0.7750
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.1, Batch Size: 32, Test Loss: 0.7932
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.1, Batch Size: 64, Test Loss: 0.8361
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.1, Batch Size: 128, Test Loss: 0.7605
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.1, Batch Size: 256, Test Loss: 0.7648
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.1, Batch Size: 512, Test Loss: 0.7468
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.7451
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.7487
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.7342
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 128, Test Loss: 0.7441
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 256, Test Loss: 0.7494
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 512, Test Loss: 0.7455
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.7479
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.7484
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.7356
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 128, Test Loss: 0.7458
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 256, Test Loss: 0.7552
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 512, Test Loss: 0.8011
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7578
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.7698
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.7772
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 128, Test Loss: 1.0439
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 256, Test Loss: 1.0152
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 512, Test Loss: 1.2357
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 10, Batch Size: 16, Test Loss: 1.3016
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 10, Batch Size: 32, Test Loss: 1.0897
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 10, Batch Size: 64, Test Loss: 1.3978
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 10, Batch Size: 128, Test Loss: 0.7998
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 10, Batch Size: 256, Test Loss: 1.5940
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 10, Batch Size: 512, Test Loss: 1.0471
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 1, Batch Size: 16, Test Loss: 8.4322
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 1, Batch Size: 32, Test Loss: 0.8386
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 1, Batch Size: 64, Test Loss: 1.6688
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 1, Batch Size: 128, Test Loss: 0.7551
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 1, Batch Size: 256, Test Loss: 0.7764
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 1, Batch Size: 512, Test Loss: 0.8368
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.1, Batch Size: 16, Test Loss: 0.8182
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.1, Batch Size: 32, Test Loss: 0.7577
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.1, Batch Size: 64, Test Loss: 0.8653
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.1, Batch Size: 128, Test Loss: 0.7634
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.1, Batch Size: 256, Test Loss: 0.7727
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.1, Batch Size: 512, Test Loss: 0.7512
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.7464
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.7419
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.7390
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 128, Test Loss: 0.7435
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 256, Test Loss: 0.7477
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 512, Test Loss: 0.7447
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.7436
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.7460
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.7346
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 128, Test Loss: 0.7440
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 256, Test Loss: 0.7514
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 512, Test Loss: 0.7697
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.7526
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.7507
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.7568
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 128, Test Loss: 1.0303
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 256, Test Loss: 0.9023
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 512, Test Loss: 1.1255
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 10, Batch Size: 16, Test Loss: 1.7556
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 10, Batch Size: 32, Test Loss: 0.9656
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 10, Batch Size: 64, Test Loss: 1.0720
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 10, Batch Size: 128, Test Loss: 1.7621
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 10, Batch Size: 256, Test Loss: 0.7620
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 10, Batch Size: 512, Test Loss: 1.0894
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 1, Batch Size: 16, Test Loss: 0.9358
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 1, Batch Size: 32, Test Loss: 0.9149
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 1, Batch Size: 64, Test Loss: 0.7841
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 1, Batch Size: 128, Test Loss: 233.9774
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 1, Batch Size: 256, Test Loss: 0.7798
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 1, Batch Size: 512, Test Loss: 0.7656
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.1, Batch Size: 16, Test Loss: 0.7916
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.1, Batch Size: 32, Test Loss: 0.8524
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.1, Batch Size: 64, Test Loss: 0.7783
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.1, Batch Size: 128, Test Loss: 0.7591
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.1, Batch Size: 256, Test Loss: 0.7488
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.1, Batch Size: 512, Test Loss: 0.7521
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.01, Batch Size: 16, Test Loss: 0.7490
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.01, Batch Size: 32, Test Loss: 0.7426
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.01, Batch Size: 64, Test Loss: 0.7365
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.01, Batch Size: 128, Test Loss: 0.7416
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.01, Batch Size: 256, Test Loss: 0.7456
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.01, Batch Size: 512, Test Loss: 0.7440
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.001, Batch Size: 16, Test Loss: 0.7430
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.001, Batch Size: 32, Test Loss: 0.7430
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.001, Batch Size: 64, Test Loss: 0.7345
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.001, Batch Size: 128, Test Loss: 0.7429
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.001, Batch Size: 256, Test Loss: 0.7498
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.001, Batch Size: 512, Test Loss: 0.7492
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.0001, Batch Size: 16, Test Loss: 0.7502
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.0001, Batch Size: 32, Test Loss: 0.7454
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.0001, Batch Size: 64, Test Loss: 0.7366
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.0001, Batch Size: 128, Test Loss: 0.7472
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.0001, Batch Size: 256, Test Loss: 0.8236
# Hidden Layers: [4], Activation: linear, Epochs: 100, LR: 0.0001, Batch Size: 512, Test Loss: 0.9424
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 10, Batch Size: 16, Test Loss: 2.7253
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 10, Batch Size: 32, Test Loss: 1279.0363
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 10, Batch Size: 64, Test Loss: 14282.9159
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 10, Batch Size: 128, Test Loss: 0.9262
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 10, Batch Size: 256, Test Loss: 1.6329
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 10, Batch Size: 512, Test Loss: 36.9783
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 1, Batch Size: 16, Test Loss: 0.9645
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 1, Batch Size: 32, Test Loss: 0.9692
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 1, Batch Size: 64, Test Loss: 0.7556
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 1, Batch Size: 128, Test Loss: 0.8560
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 1, Batch Size: 256, Test Loss: 0.9909
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 1, Batch Size: 512, Test Loss: 0.7876
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.1, Batch Size: 16, Test Loss: 0.7944
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.1, Batch Size: 32, Test Loss: 0.7846
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.1, Batch Size: 64, Test Loss: 0.7906
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.1, Batch Size: 128, Test Loss: 0.7992
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.1, Batch Size: 256, Test Loss: 0.7584
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.1, Batch Size: 512, Test Loss: 0.7461
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.01, Batch Size: 16, Test Loss: 0.7666
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.01, Batch Size: 32, Test Loss: 0.7521
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.01, Batch Size: 64, Test Loss: 0.7352
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.01, Batch Size: 128, Test Loss: 0.7428
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.01, Batch Size: 256, Test Loss: 0.7444
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.01, Batch Size: 512, Test Loss: 0.7451
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.001, Batch Size: 16, Test Loss: 0.7428
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.001, Batch Size: 32, Test Loss: 0.7436
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.001, Batch Size: 64, Test Loss: 0.7326
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.001, Batch Size: 128, Test Loss: 0.7411
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.001, Batch Size: 256, Test Loss: 0.7463
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.001, Batch Size: 512, Test Loss: 0.7469
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.0001, Batch Size: 16, Test Loss: 0.7445
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.0001, Batch Size: 32, Test Loss: 0.7467
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.0001, Batch Size: 64, Test Loss: 0.7381
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.0001, Batch Size: 128, Test Loss: 0.7457
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.0001, Batch Size: 256, Test Loss: 0.7486
# Hidden Layers: [4], Activation: linear, Epochs: 250, LR: 0.0001, Batch Size: 512, Test Loss: 0.8767
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 10, Batch Size: 16, Test Loss: 1.1911
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 10, Batch Size: 32, Test Loss: 1.0843
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 10, Batch Size: 64, Test Loss: 1.1814
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 10, Batch Size: 128, Test Loss: 21.3992
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 10, Batch Size: 256, Test Loss: 46.3398
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 10, Batch Size: 512, Test Loss: 26.2770
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 1, Batch Size: 16, Test Loss: 0.8605
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 1, Batch Size: 32, Test Loss: 0.9169
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 1, Batch Size: 64, Test Loss: 0.8004
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 1, Batch Size: 128, Test Loss: 1.0373
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 1, Batch Size: 256, Test Loss: 0.8849
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 1, Batch Size: 512, Test Loss: 0.9506
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.1, Batch Size: 16, Test Loss: 0.7580
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.1, Batch Size: 32, Test Loss: 0.7454
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.1, Batch Size: 64, Test Loss: 0.7269
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.1, Batch Size: 128, Test Loss: 0.7626
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.1, Batch Size: 256, Test Loss: 0.7830
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.1, Batch Size: 512, Test Loss: 0.8697
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.01, Batch Size: 16, Test Loss: 0.7411
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.01, Batch Size: 32, Test Loss: 0.7908
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.01, Batch Size: 64, Test Loss: 0.7710
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.01, Batch Size: 128, Test Loss: 0.8527
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.01, Batch Size: 256, Test Loss: 0.9003
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.01, Batch Size: 512, Test Loss: 0.9510
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.001, Batch Size: 16, Test Loss: 0.9151
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.001, Batch Size: 32, Test Loss: 0.9818
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.001, Batch Size: 64, Test Loss: 0.9893
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.001, Batch Size: 128, Test Loss: 1.0475
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.001, Batch Size: 256, Test Loss: 1.0156
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.001, Batch Size: 512, Test Loss: 1.1282
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.0001, Batch Size: 16, Test Loss: 1.3323
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.0001, Batch Size: 32, Test Loss: 1.1592
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.0001, Batch Size: 64, Test Loss: 1.1772
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.0001, Batch Size: 128, Test Loss: 1.1872
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.0001, Batch Size: 256, Test Loss: 1.1234
# Hidden Layers: [4], Activation: sigmoid, Epochs: 1, LR: 0.0001, Batch Size: 512, Test Loss: 1.0888
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 10, Batch Size: 16, Test Loss: 1.5815
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 10, Batch Size: 32, Test Loss: 1.0587
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 10, Batch Size: 64, Test Loss: 1.2239
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 10, Batch Size: 128, Test Loss: 0.9485
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 10, Batch Size: 256, Test Loss: 0.9091
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 10, Batch Size: 512, Test Loss: 1.0441
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 1, Batch Size: 16, Test Loss: 0.8620
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 1, Batch Size: 32, Test Loss: 1.0770
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 1, Batch Size: 64, Test Loss: 0.7402
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 1, Batch Size: 128, Test Loss: 0.7435
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 1, Batch Size: 256, Test Loss: 0.7578
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 1, Batch Size: 512, Test Loss: 0.7617
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.1, Batch Size: 16, Test Loss: 0.7171
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.1, Batch Size: 32, Test Loss: 0.7404
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.1, Batch Size: 64, Test Loss: 0.7113
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.1, Batch Size: 128, Test Loss: 0.6786
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.1, Batch Size: 256, Test Loss: 0.6894
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.1, Batch Size: 512, Test Loss: 0.7182
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6990
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.7115
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.7008
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 128, Test Loss: 0.7283
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 256, Test Loss: 0.7350
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 512, Test Loss: 0.7519
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.7417
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.7615
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.7869
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 128, Test Loss: 0.9228
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 256, Test Loss: 1.0255
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 512, Test Loss: 0.9542
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.9394
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9523
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.1018
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 128, Test Loss: 1.4429
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 256, Test Loss: 1.0021
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 512, Test Loss: 1.3274
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 10, Batch Size: 16, Test Loss: 2.9640
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 10, Batch Size: 32, Test Loss: 1.8202
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 10, Batch Size: 64, Test Loss: 1.0225
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 10, Batch Size: 128, Test Loss: 0.9961
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 10, Batch Size: 256, Test Loss: 1.1748
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 10, Batch Size: 512, Test Loss: 0.9047
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 1, Batch Size: 16, Test Loss: 0.9210
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 1, Batch Size: 32, Test Loss: 1.1842
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 1, Batch Size: 64, Test Loss: 0.7635
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 1, Batch Size: 128, Test Loss: 0.7906
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 1, Batch Size: 256, Test Loss: 0.7626
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 1, Batch Size: 512, Test Loss: 0.7420
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.1, Batch Size: 16, Test Loss: 0.7621
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.1, Batch Size: 32, Test Loss: 0.7698
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.1, Batch Size: 64, Test Loss: 0.7040
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.1, Batch Size: 128, Test Loss: 0.6994
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.1, Batch Size: 256, Test Loss: 0.7132
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.1, Batch Size: 512, Test Loss: 0.6897
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6801
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6762
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6928
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 128, Test Loss: 0.6865
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 256, Test Loss: 0.7168
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 512, Test Loss: 0.7422
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.7327
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.7407
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.7296
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 128, Test Loss: 0.7559
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 256, Test Loss: 0.8402
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 512, Test Loss: 0.9185
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7973
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9303
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9301
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 128, Test Loss: 0.9824
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 256, Test Loss: 0.9988
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 512, Test Loss: 0.9637
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 10, Batch Size: 16, Test Loss: 9.3501
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 10, Batch Size: 32, Test Loss: 15.1168
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 10, Batch Size: 64, Test Loss: 1.1614
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 10, Batch Size: 128, Test Loss: 1.0187
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 10, Batch Size: 256, Test Loss: 0.8588
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 10, Batch Size: 512, Test Loss: 0.8856
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 1, Batch Size: 16, Test Loss: 0.8268
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 1, Batch Size: 32, Test Loss: 0.8509
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 1, Batch Size: 64, Test Loss: 0.8963
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 1, Batch Size: 128, Test Loss: 0.7664
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 1, Batch Size: 256, Test Loss: 0.7049
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 1, Batch Size: 512, Test Loss: 0.7726
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.1, Batch Size: 16, Test Loss: 0.7469
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.1, Batch Size: 32, Test Loss: 0.7237
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.1, Batch Size: 64, Test Loss: 0.6837
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.1, Batch Size: 128, Test Loss: 0.7119
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.1, Batch Size: 256, Test Loss: 0.7121
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.1, Batch Size: 512, Test Loss: 0.7046
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6795
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6728
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6626
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 128, Test Loss: 0.7150
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 256, Test Loss: 0.6943
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 512, Test Loss: 0.7232
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.7069
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.7273
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.7285
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 128, Test Loss: 0.7398
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 256, Test Loss: 0.7596
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 512, Test Loss: 0.8041
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.7554
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.7940
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.8534
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 128, Test Loss: 0.9020
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 256, Test Loss: 0.9756
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 512, Test Loss: 1.0075
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 10, Batch Size: 16, Test Loss: 2.5126
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 10, Batch Size: 32, Test Loss: 1.1565
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 10, Batch Size: 64, Test Loss: 2.7943
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 10, Batch Size: 128, Test Loss: 1.1879
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 10, Batch Size: 256, Test Loss: 0.9501
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 10, Batch Size: 512, Test Loss: 0.9249
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 1, Batch Size: 16, Test Loss: 1.2129
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 1, Batch Size: 32, Test Loss: 0.8291
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 1, Batch Size: 64, Test Loss: 0.7927
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 1, Batch Size: 128, Test Loss: 0.8104
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 1, Batch Size: 256, Test Loss: 0.7421
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 1, Batch Size: 512, Test Loss: 0.7666
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.1, Batch Size: 16, Test Loss: 0.7346
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.1, Batch Size: 32, Test Loss: 0.7490
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.1, Batch Size: 64, Test Loss: 0.6815
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.1, Batch Size: 128, Test Loss: 0.7055
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.1, Batch Size: 256, Test Loss: 0.7115
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.1, Batch Size: 512, Test Loss: 0.6828
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.01, Batch Size: 16, Test Loss: 0.7350
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.01, Batch Size: 32, Test Loss: 0.6740
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.01, Batch Size: 64, Test Loss: 0.6746
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.01, Batch Size: 128, Test Loss: 0.6742
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.01, Batch Size: 256, Test Loss: 0.6688
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.01, Batch Size: 512, Test Loss: 0.7158
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.001, Batch Size: 16, Test Loss: 0.6798
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.001, Batch Size: 32, Test Loss: 0.6962
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.001, Batch Size: 64, Test Loss: 0.7111
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.001, Batch Size: 128, Test Loss: 0.7276
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.001, Batch Size: 256, Test Loss: 0.7366
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.001, Batch Size: 512, Test Loss: 0.7485
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.0001, Batch Size: 16, Test Loss: 0.7403
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.0001, Batch Size: 32, Test Loss: 0.7543
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.0001, Batch Size: 64, Test Loss: 0.7966
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.0001, Batch Size: 128, Test Loss: 0.8492
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.0001, Batch Size: 256, Test Loss: 1.0201
# Hidden Layers: [4], Activation: sigmoid, Epochs: 100, LR: 0.0001, Batch Size: 512, Test Loss: 0.9565
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 10, Batch Size: 16, Test Loss: 1.5119
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 10, Batch Size: 32, Test Loss: 2.1619
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 10, Batch Size: 64, Test Loss: 1.2604
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 10, Batch Size: 128, Test Loss: 1.4164
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 10, Batch Size: 256, Test Loss: 0.8419
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 10, Batch Size: 512, Test Loss: 0.9819
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 1, Batch Size: 16, Test Loss: 0.9601
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 1, Batch Size: 32, Test Loss: 0.7932
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 1, Batch Size: 64, Test Loss: 0.7810
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 1, Batch Size: 128, Test Loss: 0.7637
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 1, Batch Size: 256, Test Loss: 0.7611
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 1, Batch Size: 512, Test Loss: 0.7244
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.1, Batch Size: 16, Test Loss: 0.7141
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.1, Batch Size: 32, Test Loss: 0.7086
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.1, Batch Size: 64, Test Loss: 0.6962
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.1, Batch Size: 128, Test Loss: 0.7233
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.1, Batch Size: 256, Test Loss: 0.6859
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.1, Batch Size: 512, Test Loss: 0.7016
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.01, Batch Size: 16, Test Loss: 0.6904
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.01, Batch Size: 32, Test Loss: 0.6738
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.01, Batch Size: 64, Test Loss: 0.6692
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.01, Batch Size: 128, Test Loss: 0.6489
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.01, Batch Size: 256, Test Loss: 0.6839
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.01, Batch Size: 512, Test Loss: 0.6976
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.001, Batch Size: 16, Test Loss: 0.6683
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.001, Batch Size: 32, Test Loss: 0.6723
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.001, Batch Size: 64, Test Loss: 0.6999
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.001, Batch Size: 128, Test Loss: 0.7018
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.001, Batch Size: 256, Test Loss: 0.7282
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.001, Batch Size: 512, Test Loss: 0.7256
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.0001, Batch Size: 16, Test Loss: 0.7329
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.0001, Batch Size: 32, Test Loss: 0.7370
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.0001, Batch Size: 64, Test Loss: 0.7317
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.0001, Batch Size: 128, Test Loss: 0.7599
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.0001, Batch Size: 256, Test Loss: 0.7746
# Hidden Layers: [4], Activation: sigmoid, Epochs: 250, LR: 0.0001, Batch Size: 512, Test Loss: 0.8745
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 10, Batch Size: 16, Test Loss: 4.9587
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 10, Batch Size: 32, Test Loss: 15.3968
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 10, Batch Size: 64, Test Loss: 399.3653
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 10, Batch Size: 128, Test Loss: 3834.1892
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 10, Batch Size: 256, Test Loss: 127502.3652
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 10, Batch Size: 512, Test Loss: 66081.7969
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 1, Batch Size: 16, Test Loss: 1.0074
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 1, Batch Size: 32, Test Loss: 1.2085
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 1, Batch Size: 64, Test Loss: 1.1268
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 1, Batch Size: 128, Test Loss: 1.1215
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 1, Batch Size: 256, Test Loss: 1.2949
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 1, Batch Size: 512, Test Loss: 12.1004
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.1, Batch Size: 16, Test Loss: 0.7517
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.1, Batch Size: 32, Test Loss: 0.8294
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.1, Batch Size: 64, Test Loss: 0.7274
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.1, Batch Size: 128, Test Loss: 0.7539
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.1, Batch Size: 256, Test Loss: 0.7549
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.1, Batch Size: 512, Test Loss: 0.7722
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.01, Batch Size: 16, Test Loss: 0.7568
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.01, Batch Size: 32, Test Loss: 0.7271
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.01, Batch Size: 64, Test Loss: 0.7314
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.01, Batch Size: 128, Test Loss: 0.7437
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.01, Batch Size: 256, Test Loss: 0.9193
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.01, Batch Size: 512, Test Loss: 0.9284
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.001, Batch Size: 16, Test Loss: 0.8221
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.001, Batch Size: 32, Test Loss: 0.8506
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.001, Batch Size: 64, Test Loss: 0.9062
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.001, Batch Size: 128, Test Loss: 1.0921
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.001, Batch Size: 256, Test Loss: 1.0104
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.001, Batch Size: 512, Test Loss: 1.2681
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.0001, Batch Size: 16, Test Loss: 1.0286
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.0001, Batch Size: 32, Test Loss: 1.0133
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.0001, Batch Size: 64, Test Loss: 1.1840
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.0001, Batch Size: 128, Test Loss: 1.0638
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.0001, Batch Size: 256, Test Loss: 1.1507
# Hidden Layers: [4], Activation: relu, Epochs: 1, LR: 0.0001, Batch Size: 512, Test Loss: 1.0930
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 10, Batch Size: 16, Test Loss: 3.4964
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 10, Batch Size: 32, Test Loss: 146.7065
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 10, Batch Size: 64, Test Loss: 4812.5500
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 10, Batch Size: 128, Test Loss: 1.1162
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 10, Batch Size: 256, Test Loss: 69.2578
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 10, Batch Size: 512, Test Loss: 91.2757
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 1, Batch Size: 16, Test Loss: 1.0117
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 1, Batch Size: 32, Test Loss: 1.1127
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 1, Batch Size: 64, Test Loss: 1.3099
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 1, Batch Size: 128, Test Loss: 0.9166
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 1, Batch Size: 256, Test Loss: 0.9471
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 1, Batch Size: 512, Test Loss: 0.8926
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.1, Batch Size: 16, Test Loss: 0.8257
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.1, Batch Size: 32, Test Loss: 0.7333
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.1, Batch Size: 64, Test Loss: 0.7180
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.1, Batch Size: 128, Test Loss: 0.6961
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.1, Batch Size: 256, Test Loss: 0.6683
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.1, Batch Size: 512, Test Loss: 0.7362
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6872
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6883
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6827
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 128, Test Loss: 0.6796
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 256, Test Loss: 0.7262
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 512, Test Loss: 0.7163
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6917
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.7067
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.7294
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 128, Test Loss: 0.7443
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 256, Test Loss: 0.7996
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 512, Test Loss: 0.9283
# ...
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 512, Test Loss: 0.7357
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.7249
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.7293
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.7124
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 128, Test Loss: 0.7306
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 256, Test Loss: 0.7570
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 512, Test Loss: 0.9238
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.8020
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.7906
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.8647
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 128, Test Loss: 0.8914
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 256, Test Loss: 1.0020
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 512, Test Loss: 1.1789
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 10, Batch Size: 16, Test Loss: 23.8801
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 10, Batch Size: 32, Test Loss: 1.9287
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 10, Batch Size: 64, Test Loss: 24.6938
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 10, Batch Size: 128, Test Loss: 1.1130
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 10, Batch Size: 256, Test Loss: 0.9160
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 10, Batch Size: 512, Test Loss: 0.9978
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 1, Batch Size: 16, Test Loss: 3.2805
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 1, Batch Size: 32, Test Loss: 1.4760
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 1, Batch Size: 64, Test Loss: 1.0116
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 1, Batch Size: 128, Test Loss: 1.4619
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 1, Batch Size: 256, Test Loss: 0.9620
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 1, Batch Size: 512, Test Loss: 0.9374
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.1, Batch Size: 16, Test Loss: 0.9696
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.1, Batch Size: 32, Test Loss: 0.8590
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.1, Batch Size: 64, Test Loss: 0.7759
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.1, Batch Size: 128, Test Loss: 0.7333
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.1, Batch Size: 256, Test Loss: 0.7459
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.1, Batch Size: 512, Test Loss: 0.6998
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.7077
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6934
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6632
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 128, Test Loss: 0.6611
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 256, Test Loss: 0.6921
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 512, Test Loss: 0.6767
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6997
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.7010
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.7092
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 128, Test Loss: 0.7054
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 256, Test Loss: 0.7377
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 512, Test Loss: 0.7478
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7468
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.7364
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.8000
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 128, Test Loss: 0.8267
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 256, Test Loss: 0.8300
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 512, Test Loss: 0.9351
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 10, Batch Size: 16, Test Loss: 10.6604
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 10, Batch Size: 32, Test Loss: 9.3071
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 10, Batch Size: 64, Test Loss: 8.3255
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 10, Batch Size: 128, Test Loss: 18.8870
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 10, Batch Size: 256, Test Loss: 0.9437
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 10, Batch Size: 512, Test Loss: 1.0150
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 1, Batch Size: 16, Test Loss: 4.7044
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 1, Batch Size: 32, Test Loss: 1.0444
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 1, Batch Size: 64, Test Loss: 1.6365
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 1, Batch Size: 128, Test Loss: 1.1412
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 1, Batch Size: 256, Test Loss: 1.2767
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 1, Batch Size: 512, Test Loss: 1.4101
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.1, Batch Size: 16, Test Loss: 0.8580
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.1, Batch Size: 32, Test Loss: 0.8528
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.1, Batch Size: 64, Test Loss: 0.8159
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.1, Batch Size: 128, Test Loss: 0.7515
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.1, Batch Size: 256, Test Loss: 0.7844
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.1, Batch Size: 512, Test Loss: 0.6803
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6867
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6643
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6519
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 128, Test Loss: 0.6628
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 256, Test Loss: 0.6681
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 512, Test Loss: 0.6770
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6725
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6651
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6939
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 128, Test Loss: 0.6910
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 256, Test Loss: 0.6994
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 512, Test Loss: 0.7174
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.7229
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.7446
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.7230
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 128, Test Loss: 0.7794
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 256, Test Loss: 0.8128
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 512, Test Loss: 0.9317
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 10, Batch Size: 16, Test Loss: 4.8484
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 10, Batch Size: 32, Test Loss: 1.0481
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 10, Batch Size: 64, Test Loss: 3.2153
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 10, Batch Size: 128, Test Loss: 26.9740
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 10, Batch Size: 256, Test Loss: 50.0546
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 10, Batch Size: 512, Test Loss: 1.0408
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 1, Batch Size: 16, Test Loss: 1.3559
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 1, Batch Size: 32, Test Loss: 0.9689
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 1, Batch Size: 64, Test Loss: 0.9651
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 1, Batch Size: 128, Test Loss: 0.9861
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 1, Batch Size: 256, Test Loss: 1.7787
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 1, Batch Size: 512, Test Loss: 0.9092
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.1, Batch Size: 16, Test Loss: 1.0017
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.1, Batch Size: 32, Test Loss: 0.9714
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.1, Batch Size: 64, Test Loss: 0.9088
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.1, Batch Size: 128, Test Loss: 0.7365
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.1, Batch Size: 256, Test Loss: 0.7520
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.1, Batch Size: 512, Test Loss: 0.6901
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.01, Batch Size: 16, Test Loss: 0.6868
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.01, Batch Size: 32, Test Loss: 0.6903
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.01, Batch Size: 64, Test Loss: 0.6538
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.01, Batch Size: 128, Test Loss: 0.6704
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.01, Batch Size: 256, Test Loss: 0.6561
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.01, Batch Size: 512, Test Loss: 0.6572
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.001, Batch Size: 16, Test Loss: 0.6624
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.001, Batch Size: 32, Test Loss: 0.6747
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.001, Batch Size: 64, Test Loss: 0.6907
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.001, Batch Size: 128, Test Loss: 0.6956
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.001, Batch Size: 256, Test Loss: 0.6866
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.001, Batch Size: 512, Test Loss: 0.6801
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.0001, Batch Size: 16, Test Loss: 0.7165
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.0001, Batch Size: 32, Test Loss: 0.7328
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.0001, Batch Size: 64, Test Loss: 0.7208
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.0001, Batch Size: 128, Test Loss: 0.7416
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.0001, Batch Size: 256, Test Loss: 0.7399
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 100, LR: 0.0001, Batch Size: 512, Test Loss: 0.8284
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 10, Batch Size: 16, Test Loss: 32.7934
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 10, Batch Size: 32, Test Loss: 42.4308
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 10, Batch Size: 64, Test Loss: 7.8516
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 10, Batch Size: 128, Test Loss: 27.9997
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 10, Batch Size: 256, Test Loss: 14.0157
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 10, Batch Size: 512, Test Loss: 2.8509
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 1, Batch Size: 16, Test Loss: 1.0207
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 1, Batch Size: 32, Test Loss: 3.0602
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 1, Batch Size: 64, Test Loss: 2.8590
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 1, Batch Size: 128, Test Loss: 2.1253
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 1, Batch Size: 256, Test Loss: 1.2316
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 1, Batch Size: 512, Test Loss: 1.1980
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.1, Batch Size: 16, Test Loss: 1.0492
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.1, Batch Size: 32, Test Loss: 1.0314
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.1, Batch Size: 64, Test Loss: 0.8340
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.1, Batch Size: 128, Test Loss: 0.8207
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.1, Batch Size: 256, Test Loss: 0.7546
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.1, Batch Size: 512, Test Loss: 0.7121
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.01, Batch Size: 16, Test Loss: 0.6632
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.01, Batch Size: 32, Test Loss: 0.6807
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.01, Batch Size: 64, Test Loss: 0.6184
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.01, Batch Size: 128, Test Loss: 0.6588
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.01, Batch Size: 256, Test Loss: 0.6434
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.01, Batch Size: 512, Test Loss: 0.6524
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.001, Batch Size: 16, Test Loss: 0.6592
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.001, Batch Size: 32, Test Loss: 0.6617
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.001, Batch Size: 64, Test Loss: 0.6504
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.001, Batch Size: 128, Test Loss: 0.6621
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.001, Batch Size: 256, Test Loss: 0.6721
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.001, Batch Size: 512, Test Loss: 0.6736
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.0001, Batch Size: 16, Test Loss: 0.6927
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.0001, Batch Size: 32, Test Loss: 0.7092
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.0001, Batch Size: 64, Test Loss: 0.7030
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.0001, Batch Size: 128, Test Loss: 0.7227
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.0001, Batch Size: 256, Test Loss: 0.7196
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 250, LR: 0.0001, Batch Size: 512, Test Loss: 0.7455
